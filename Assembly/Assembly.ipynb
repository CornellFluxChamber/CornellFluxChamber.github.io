# %% [markdown]
# # Assembly Instructions
#
# *Written by Grace Lo*
#
# > - [Electronics](#Electronics-Assembly)
# >   - [Flashing the Raspberry Pi Pico](#Flashing-the-Raspberry-Pi-Pico)
# > - [Chamber](#Chamber-Assembly)

# %% [markdown]
# ## Electronics Parts List
#
# *Note: Prices are prorated.*
#
# | Item | Part Number | Quantity | Price ($) | Notes |
# |---|---|---|---|---|
# | [Raspberry Pi Pico](https://www.adafruit.com/product/5525) (with Pre-Soldered Headers)                                          |               | 1 | 5.00  ||
# | [Figaro Methane Sensor](https://www.figarosensor.com/product/entry/ngm2611.html)                                                | NGM2611-E13   | 1 | 28.00 ||
# | [Sensirion CO₂ Sensor](https://sensirion.com/products/catalog/SCD30)                                                            | SCD30         | 1 | 33.24 ||
# | [MicroSD Card Breakout Board](https://www.adafruit.com/product/254)                                                             |               | 1 | 7.50  ||
# | [MicroSD Card](https://shop.sandisk.com/products/memory-cards/microsd-cards/sandisk-ultra-uhs-i-microsd?sku=SDSQUNC-016G-AN6MA) |               | 1 | 6.19  ||
# | [Adafruit Stepper Motor Driver Breakout Board](https://www.adafruit.com/product/6121)                                           | TMC2209       | 1 | 8.95  ||
# | [NEMA 17 Stepper Motor with Integrated 300mm T8 Lead Screw](https://www.amazon.com/Iverntech-Stepper-Integrated-Printers-Machine/dp/B07D6GC4C4)<br>(includes motor nut)|| 1 | 26.99 | Or equivalent with total length (motor body + lead screw) of ~31 cm. |
# | [Limit Switch](https://www.digikey.com/en/products/detail/omron-electronics-inc-emc-div/SS-5GL-3D/5236961)                      | SS-5GL-3D     | 1 | 1.77  ||
# | [Float Switch](https://www.digikey.com/en/products/detail/pic-gmbh/PLS-031B-3PAI/9687296)                                       | PLS-031B-3PAI | 1 | 3.60  ||
# | [PCB (Main & Limit Switch)](https://jlcpcb.com/)                                                                                |               | 1 | 1.20  | Minimum of 5 per order. |
# | [2-Hole Screw Terminal 2.54mm Pitch](https://www.digikey.com/en/products/detail/on-shore-technology-inc/OSTVN02A150/1588862)    | OSTVN02A150   | 3 | 2.61  ||
# | Barrel Jack to Wire Leads Adapter                                                                                               |               | 1 | 2.00  ||
# | 1kΩ Resistor                                                                                                                    |               | 1 | 0.10  ||
# | [NPN Transistor](https://www.digikey.com/en/products/detail/diotec-semiconductor/2N3904/13164701)                               |               | 1 | 0.14  ||
# | 1x3 Male Header Pin                                                                                                             |               | 1 | 0.10  ||
# | *Female Socket Pin Headers:*                                                                                                    |               |   |       ||
# | &nbsp; 1x5                                                                                                                      |               | 1 | 0.10  ||
# | &nbsp; 1x7                                                                                                                      |               | 1 | 0.10  ||
# | &nbsp; 1x8                                                                                                                      |               | 1 | 0.10  ||
# | &nbsp; 1x10                                                                                                                     |               | 1 | 0.10  ||
# | &nbsp; 1x20                                                                                                                     |               | 2 | 0.20  ||
# | **Total**                                                                                                                       |               |   | **127.99** ||
#
# *Tools:*
# - Soldering Iron
# - Wire Stripper
# - Diagonal Cutter
# - [Raspberry Pi Debug Probe](https://www.raspberrypi.com/products/debug-probe/) (optional)

# %% [markdown]
# ## Electronics Assembly
#
# The electronic system uses header pins to create a modular design, where components can be easily replaced in case of failure.
#
# 1. Solder.
#     - Male header pins (included in package) for the breakout boards (CO₂ sensor, microSD card breakout board, motor driver).
#
#         <img src="img/electronic_assembly/step1a.png" alt="Step 1a" width="250"/>
#
#     - Header pins and other parts (screw terminals, 1kΩ resistor, NPN transistor, limit switch) for the PCBs.
#
#         <img src="img/electronic_assembly/step1b.png" alt="Step 1b" width="300"/>
#
#     - Use diagonal cutters to trim the ends of the limit switch and screw terminals to be relatively flush with the PCB (in particular, the limit switch PCB should lay flat on the motor - see step 6 of [Chamber Assembly](#Chamber-Assembly)).
#
# 2. Cut excess motor cable (leave ~3-in) and strip the motor cable to access the 4 wires. For longevity, it is suggested to solder each of the multi-threaded wires.
#
#     <img src="img/electronic_assembly/step2.png" alt="Step 2" width="300"/>
#
# 3. Plug in sensors according to the picture.
#     - The screw terminal wires should be left out to connect later in the assembly process.
#     - There are also detailed wiring diagrams in the **Electrical design** section of the [main webpage](../index.html).
#
#         <img src="img/electronic_assembly/step3.png" alt="Step 3" width="400"/>
#
# 4. Flash the code onto the Raspberry Pi Pico (see next section).

# %% [markdown]
# ### Flashing the Raspberry Pi Pico
#
# The code must be loaded onto the Pico every time there is a change.
#
# 1. On your laptop's command-line interface (Terminal for macOS/Linux or PowerShell for Windows):
#     - Navigate to the folder you want to store the code using `cd [your_path]`
#     - Then clone the [CornellFluxChamber](https://github.com/CornellFluxChamber/ChamberCode) Github repository using `git clone https://github.com/CornellFluxChamber/ChamberCode.git`
# 2. Download [Visual Studio Code](https://code.visualstudio.com/) if you don't have it already and install the *Raspberry Pi Pico* and *Serial Monitor* extensions.
#
#     <img src="img/flash_pico/step2a.png" alt="Step 2a" width="300"/>
#     <img src="img/flash_pico/step2b.png" alt="Step 2b" width="300"/>
#
# 3. Click the Pico extension on the left sidebar and "Import Project" by changing the location to the `ChamberCode` project folder (eg. `[your_path]/ChamberCode/CornellFluxChamber`).
#     - Note: We cloned the whole `ChamberCode` repository, but we only want to open the `CornellFluxChamber` project.
#     - The chamber code has a `CUSTOMIZABLE PARAMETERS` section to change:
#         - Filename
#         - Date/time
#         - Total sampling time per cycle
#         - Sampling interval between each measurement
#         - Total chamber flush time per cycle
#         - Debug boolean
#
#         For more information, see the [Flux Chamber](./Flux_Chamber/Flux_Chamber.html) page.
# 4. A new window will open with a list of the contents on the left. Click "Compile" at the bottom of the screen to build the project.
#     - Note: There are 2 known warnings when compiling the code, but it does not affect the functionality of the system.
#
#         <img src="img/flash_pico/step4.png" alt="Step 4" width="700"/>
#
# 5. Hold down the Bootsel button and plug the USB cable into your laptop. Then click the "Run" icon at the bottom of the screen to flash the Pico.
#
# There are 2 ways to verify correct setup:
# 1. Let the system run for 1 minute, then power it off and read the SD card contents.
# 2. There is a serial monitor displaying real-time information about the running system for use during initial setup.
#     - Connect the [Raspberry Pi Debug Probe](https://www.raspberrypi.com/products/debug-probe/) via:
#         - PCB TX &rarr; debug probe RX (yellow)
#         - PCB RX &rarr; debug probe TX (orange)
#         - PCB GND &rarr; debug probe GND (black)
#         - USB &rarr; laptop
#     - Then go to the `flux_chamber.c` file, find the `CUSTOMIZABLE PARAMETERS` section, and change `debug_mode = true`.
#     - "Compile" the changes.
#     - Go to the "Serial Monitor" tab and set the port to the one ending in "Raspberry Pi." Then "Start Monitoring."
#     - "Run" it on the Pico.
#
# <div style="text-align:center;">
#     <img src="img/vscode_window.png" alt="Visual Studio Code Window" width="800"/>
# </div>

# %% [markdown]
# ## Chamber Parts List
#
# *Note: Prices are prorated.*
#
# | Item | Part Number | Quantity | Price ($) | Notes |
# |---|---|---|---|---|
# | [1/8" Thick x 12" x 12" Acrylic](https://www.amazon.com/MIKING-Plexiglass-Transparent-Protective-Crafting/dp/B09FHYDGM1)                                 |           | 2      | 10.00  ||
# | [1/2-in x 10-ft PVC Pipe](https://www.lowes.com/pd/Charlotte-Pipe-1-2-in-dia-x-10-ft-L-600-PSI-PVC-Pipe/3133079)<br>[1/2-in x 2-ft PVC Pipe](https://www.lowes.com/pd/Charlotte-Pipe-1-2-in-dia-x-2-ft-L-600-PSI-PVC-Pipe/3341538)                                                                                                                                                   |           | 1<br>3 | 14.20  | 16-ft total cut into 12 x 1-ft and 4 x 10-in pieces. |
# | [1/2-in PVC 3-Way Elbow](https://www.lowes.com/pd/PVC-Pipeworks-1-2-in-x-1-2-in-x-1-2-in-x-1-2-in-dia-Side-Outlet-Elbow-PVC-Fitting-10-Pack/1001732344)  |           | 4      | 6.80   ||
# | [1/2-in PVC 4-Way Elbow](https://www.lowes.com/pd/PVC-Pipeworks-1-2-in-x-1-2-in-x-1-2-in-x-1-2-in-x-1-2-in-dia-Cross-Tee-PVC-Fitting-10-Pack/1001732812) |           | 4      | 8.00   ||
# | [7/8-in Stainless Steel Loop Clamp](https://www.amazon.com/LOKMAN-Stainless-Cushioned-Insulated-Installation/dp/B01ISZLHEG)                              |           | 12     | 8.99   ||
# | [10-in Diameter PVC Flexible Duct](https://www.lowes.com/pd/Rubber-Cal-HVAC-Ventilation-10-in-x-300-in-PVC-Flexible-Duct/5003827583)                     |           | 14-in  | 2.27   | Cut 14-in section & seal the top/bottom wire opening with caulk.  |
# | [Silicone Caulk](https://www.lowes.com/pd/GE-Silicone-1-All-Purpose-Windows-Doors-Exteriors-10-1-oz-Clear-Silicone-Caulk/5013443639)                     |           | 1      | 8.88   ||
# | Pool Noodle                                                                                                                                              |           | 2      | 2.00   | Cut 8 x 10.5-in pieces. |
# | Small Binder Clip                                                                                                                                        |           | 4      | 0.40   ||
# | *Nuts and Bolts:*                                                                                                                                        |           |        |        ||
# | &nbsp; [M3 × 0.5-mm x 6-mm Machine Screw](https://www.mcmaster.com/92005A116/)                                                                           | 92005A116 | 4      | 0.18   ||
# | &nbsp; [M3 × 0.5-mm x 10-mm Machine Screw](https://www.mcmaster.com/92005A120/)                                                                          | 92005A120 | 8      | 0.35   ||
# | &nbsp; [M3 × 0.5-mm x 40-mm Machine Screw](https://www.mcmaster.com/92005A135/)                                                                          | 92005A135 | 4      | 0.45   | Length of screw should match length of motor body (ie. 40-mm screw for a 39.5-mm body). |
# | &nbsp; [M3 × 0.5-mm Hex Nut](https://www.mcmaster.com/90591A121/)                                                                                        | 90591A121 | 4      | 0.08   ||
# | &nbsp; [M3 Washer](https://www.mcmaster.com/91166A210/)                                                                                                  | 91166A210 | 8      | 0.18   ||
# | &nbsp; [#8-32 x 5/8-in Machine Screw](https://www.mcmaster.com/90272A196/)                                                                               | 90272A196 | 8      | 0.37   | Screw size is flexible as long as the screw fits a 6.5-mm hole. |
# | &nbsp; [#8-32 Hex Nut](https://www.mcmaster.com/90480A009/)                                                                                              | 90480A009 | 8      | 0.16   | Nut size to fit chosen screw. |
# | [Portable Battery](https://voltaicsystems.com/v88/?srsltid=AfmBOoo9PaF4oLNwP4vonrxR4gKMhDIm0SLCi3NDAY8eFSJ0FpnUzNSK) (*not included in total price*)     |           | 1      | 149.00 ||
# | [1-in x 3-in Velcro](https://www.amazon.com/Art3d-Sticky-Double-Sided-Command-Adhesive/dp/B0C4L1L696)                                                    |           | 1      | 0.58   ||
# | [Waterproof Tarp](https://www.lowes.com/pd/Sigman-Sigman-6-ft-x-8-ft-Blue-Tarp-Tarp-For-Roofing-Construction-and-Landscaping-5-Mil-Thickness/5005338055) |           | 1      | 0.70   | Cut 22-in x 22-in square. |
# | [Electrical Tape](https://www.lowes.com/pd/Scotch-700-Electrical-Tape-66-ft/50148224)                                                                    |           | 1      | 2.98   ||
# | **Total**                                                                                                                                                |           |        | **64.59** ||
#
# *Tools:*
# - Caulk Gun
# - \#2 Phillips Head Screwdriver
# - Flathead Screwdriver (2.5-mm)

# %% [markdown]
# ## Chamber Assembly
#
# 1. Laser cut the acrylic top and support with templates provided in the [CornellFluxChamber](https://github.com/CornellFluxChamber/ChamberCode/tree/master/CornellFluxChamber/LaserCutTemplates) Github repository.
#     - If you do not have access to a laser cutter, drill holes for the acrylic top and replace the acrylic support with [flexible lighting panel](https://www.homedepot.com/p/TUFFLENS-24-in-x-48-in-x-060-in-Clear-Polycarbonate-Lighting-Panel-17349102/310566151), which is easier to cut with heavy duty scissors/craft knife.
#
# 2. Orient the acrylic top according to the photo and caulk the duct, ensuring no air gaps. Let it dry before proceeding.
#     - *Don't make the same mistake I did, double check your orientation or else the PCBs will not fit properly!*
#
#     <img src="img/chamber_assembly/step2.png" alt="Step 2" width="400"/>
#
# 3. Build the structure.
#     - Thread pool noodles through 4 1-ft pipes for the base.
#     - Using the 10-in pipes as the sides, connect the pipes with 3-way elbows on the top and 4-way elbows on the bottom.
#
# 4. Secure the acrylic top to the structure using loop clamps and #8-32 nuts/screws.
#     - *Tip: Squeeze the loop clamps to align its holes before threading the screw.*
#
#     <img src="img/chamber_assembly/step4a.png" alt="Step 4a" width="300"/><img src="img/chamber_assembly/step4b.png" alt="Step 4b" width="300"/>
#
# 5. Attach the motor nut (included with the motor) and the float switch.
#
#     - Thread the long end of the motor nut through the center of the acrylic support and attach it using 4 M3 x 10-mm screws.
#     - Connect the float switch with the float facing up.
#
#         <img src="img/chamber_assembly/step5a.png" alt="Step 5a" width="210"/><img src="img/chamber_assembly/step5b.png" alt="Step 5b" width="280"/>
#
# 6. Mount the PCBs.
#     1. Remove the original screws in the motor and then screw the limit switch PCB to the underside of the motor using 4 M3 x 6-mm screws.
#         - **Beware of tightening it too much as it could hinder motor movement.**
#         - The limit switch and motor cable port should be on the same side.
#     2. Mount the motor to the center of the acrylic top using 4 M3 x 40-mm screws, with washers on the acrylic side to distribute the forces.
#         - The motor should be oriented such that its cable port faces the cable through-hole of the acrylic.
#     3. Mount the main PCB to the acrylic top using 4 M3 x 10-mm screws. Again, the washers are placed on the acrylic side and nuts are secured on the PCB side.
#         - The PCB should be oriented such that the Raspberry Pi Pico power port faces outward and the motor driver is closer to the cable through-hole side of the acrylic.
#     4. Connect the limit switch wires between the PCBs and the motor cable between the motor and the main PCB.
#
#         <img src="img/chamber_assembly/step6a.png" alt="Step 6a" width="301"/><img src="img/chamber_assembly/step6b.png" alt="Step 6b" width="400"/>
#
# 7. Pull the motor and Pico power cables through the cable through-hole toward the side of the acrylic, then caulk the hole to seal it shut.
#
# 8. Thread the acrylic support piece onto the motor rod, with the float of the float switch facing outward. Rotate the support piece until it is at the desired maximum height (when the canopy is fully open, the float switch should touch the surface of the water to indicate the end point).
#     - Now is the time to screw the float switch wires into the main PCB.
#
#     <img src="img/chamber_assembly/step8a.png" alt="Step 8a" width="300"/><img src="img/chamber_assembly/step8b.png" alt="Step 8b" width="300"/>
#
# 9. Fully extend the duct and use binder clips to secure it to the acrylic support.
#
#     <img src="img/chamber_assembly/step9.png" alt="Step 9" width="300"/>
#
# 10. Finishing touches.
#     - Flip the chamber over and place electrical tape over the exposed screws to electrically isolate them.
#     - Secure the portable battery to the top of the structure using velcro on the battery and acrylic.
#     - Place the tarp over the chamber such that rain water can fall off the edges, securing each corner to the structure using and duct tape.
#     - For extra buoyancy, thread pool noodles on the last 4 1-ft pipes and connect these support legs to the 4-way elbows of the chamber structure.
#
#         <img src="img/chamber_assembly/step10.png" alt="Step 10" width="400"/>
