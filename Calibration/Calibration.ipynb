# %% [markdown]
# # Calibration Notes
#
# *Written by Grace Lo*
#
# *This is a WIP page with calibration notes that may be helpful.*

# %% [markdown]
# From what I understand, the previous prototype read voltage readings from the [Figaro NGM2611-E13](https://www.figarosensor.com/product/entry/ngm2611.html) methane sensor and later post-processed the data for ppm readings.
#
# The current setup provides methane data in raw analog values. I propose the code stays as is to maintain the highest level of precision and reduce computation during deployment, then the raw analog values can be post-processed using the following conversion sequence:
#
# <img src="img/conversion.png" alt="Conversion Equations" width="400"/>
#
# where
# - V<sub>C</sub> = V<sub>IN</sub> = 5
# - [R<sub>L</sub> = 1.1k-4.7kΩ](https://www.figarosensor.com/product/docs/ngm2611-e13_product%20information%28fusa%29_rev03.pdf)
# - PPM uses the graph from [TGS 2611-E00](https://www.figarosensor.com/product/docs/tgs2611-e00_product_information%28fusa%29_rev02.pdf)
